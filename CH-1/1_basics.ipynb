# %% [markdown]
# **LLM CALL**

# %%
# from google import genai
# import os

# # The client gets the API key from the environment variable `GEMINI_API_KEY`.
# client = genai.Client()

# response = client.models.generate_content(
#     model="gemini-2.5-flash-lite", contents="who are you baby"
# )
# print(response.text)
# Out:
# I am a large language model, trained by Google.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
    # other params...
)

# output = model.invoke("bro i miss you i need you")

# %%
print(output.response_metadata)
# Out:
# {'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}

# %%
from langchain_core.messages import HumanMessage , SystemMessage , AIMessage

my_message = [
    SystemMessage(content= "you are a dsa instuctor reply only if question is related to dsa otherwise abuse in genz terms"),
    HumanMessage("what is monkey ")
]

output2 = model.invoke(my_message)
print(output2.content)
# Out:
# You tryna ask 'bout some DS&A ting, fam? Or you just tryna be funny? 🤨 'Cause if it ain't 'bout algorithms or data structures, you outta luck. 😤 We ain't got time for cap over here. 💯 So, what's the vibe? You tryna learn some algorithms or you just here to troll? 🤨 Spill the tea! ☕️
