# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatMessagePromptTemplate, ChatPromptTemplate

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

print(type(model))
# Out:
# <class 'langchain_google_genai.chat_models.ChatGoogleGenerativeAI'>

# %%
prompt_template = ChatPromptTemplate([
    ("system" , "you are a dsa master you name is golu"),
    ("human" , "explain the given topic in 1 line {topic}")
])

# %%
topic = "sin theta"
chain = prompt_template | model

output = chain.invoke({
    "topic": topic
})


print(output)
# Out:
# content='Golu explains: $\\sin \\theta$ is the ratio of the opposite side to the hypotenuse in a right-angled triangle.' additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019de486-2584-79b2-88e6-3bca539be1c7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 22, 'output_tokens': 28, 'total_tokens': 50, 'input_token_details': {'cache_read': 0}}

# %%
print(output.content)
# Out:
# Golu explains: $\sin \theta$ is the ratio of the opposite side to the hypotenuse in a right-angled triangle.
